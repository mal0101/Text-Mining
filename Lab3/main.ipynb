# %% [markdown]
# L’objectif de ce TP est de classifier un texte par l’implémentation d’un algorithme d’apprentissage
# supervisé – classification.
#
# **Rappel**
#
# La technique ou le modèle de classification tente de tirer des conclusions à partir des valeurs observées.
# Dans le problème de classification, nous avons les résultats catégorisés tels que «Noir» ou «Blanc»;
# «Sport», «Politique», «Économie» ou «Art». Lors de la création du modèle de classification, nous avons
# besoin d'un jeu de données (Corpus) d'entraînement contenant des points de données et les étiquettes
# correspondantes. Par exemple, si nous voulons vérifier si l'image est celle d'une voiture ou non. Pour vérifier
# cela, nous allons construire un jeu de données d'apprentissage (training) ayant les deux classes liées à
# «voiture» et «pas de voiture». Ensuite, nous devons former le modèle à l'aide des exemples d'apprentissage.
# Les modèles de classification sont principalement utilisés dans la reconnaissance faciale, la classification
# du textes, l'identification des spams, etc.
# Étapes de construction d'un classificateur en Python
# Pour construire un classificateur en Python, nous allons utiliser Python 3 et Scikit-learn qui est un outil
# d'apprentissage automatique. Suivez ces étapes pour construire un classificateur en Python

# %% [markdown]
# ## Étape 1: Importer Scikit-learn
#
# Ce serait la toute première étape pour construire un classificateur en Python. Dans cette étape, nous installerons un package Python appelé Scikit-learn qui est l'un des meilleurs modules d'apprentissage
# automatique en Python. La commande suivante nous aidera à importer le package
#
# ## Étape 2: Importer l'ensemble de données de Scikit-learn
#
# Dans cette étape, nous pouvons commencer à travailler avec l'ensemble de données pour notre modèle
# d'apprentissage automatique. Ici, nous allons utiliser l'ensemble de données 20 Newsgroups qu'est une
# collection d'environ 20 000 documents de groupes de discussion, partitionnés (presque) de manière égale
# entre 20 groupes de discussion différents.
# Dans la suite, nous utiliserons le chargeur de jeu de données intégré pour 20 newsgroups de scikit-learn.
# Il est également possible de télécharger manuellement l'ensemble de données à partir du site Web
# (http://qwone.com/~jason/20Newsgroups/)et d'utiliser la fonction sklearn.datasets.load_files en le
# pointant sur le 20news-bydate-train dossier d'archive non compressé.
# À l'aide de la commande suivante, nous pouvons importer l'ensemble de données 20 Newsgroups de

# %%
import sklearn
from sklearn.datasets import fetch_20newsgroups

# %%
data = fetch_20newsgroups()

# %%
type(data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(dir(data))
# Out:
# ['DESCR', 'data', 'filenames', 'target', 'target_names']

# %%
data.target
# Out:
# array([7, 4, 4, ..., 3, 1, 8])

# %%
data.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
data.data[:2]
# Out:
# ["From: lerxst@wam.umd.edu (where's my thing)\nSubject: WHAT car is this!?\nNntp-Posting-Host: rac3.wam.umd.edu\nOrganization: University of Maryland, College Park\nLines: 15\n\n I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.\n\nThanks,\n- IL\n   ---- brought to you by your neighborhood Lerxst ----\n\n\n\n\n",
# ...

# %%
for i in range(20):
    print("Classe: %s, Nombre textes: %s" % (i, len(data.target[ data.target == i])))
# Out:
# Classe: 0, Nombre textes: 480
# Classe: 1, Nombre textes: 584
# Classe: 2, Nombre textes: 591
# Classe: 3, Nombre textes: 590
# Classe: 4, Nombre textes: 578
# Classe: 5, Nombre textes: 593
# Classe: 6, Nombre textes: 585
# Classe: 7, Nombre textes: 594
# Classe: 8, Nombre textes: 598
# Classe: 9, Nombre textes: 597
# Classe: 10, Nombre textes: 600
# Classe: 11, Nombre textes: 595
# Classe: 12, Nombre textes: 591
# Classe: 13, Nombre textes: 594
# Classe: 14, Nombre textes: 593
# Classe: 15, Nombre textes: 599
# Classe: 16, Nombre textes: 546
# Classe: 17, Nombre textes: 564
# Classe: 18, Nombre textes: 465
# Classe: 19, Nombre textes: 377

# %%
len(data.target)
# Out:
# 11314

# %%
categories = ["comp.os.ms-windows.misc", "comp.sys.ibm.pc.hardware", "comp.sys.mac.hardware", "comp.windows.x"]

# %%
dataset = fetch_20newsgroups(
    subset = 'train',
    categories = categories,
    shuffle = True,
    random_state = 42
)

# %%
dataset.target_names
# Out:
# ['comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x']

# %%
for i in range(4):
    print("Classe: %s, Nombre textes: %s" % (i, len(dataset.target[ dataset.target == i])))
# Out:
# Classe: 0, Nombre textes: 591
# Classe: 1, Nombre textes: 590
# Classe: 2, Nombre textes: 578
# Classe: 3, Nombre textes: 593

# %% [markdown]
# ## Étape 3: Organisation des données

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(dataset.data)
X_train_counts.shape
# Out:
# (2352, 60987)

# %%
count_vect.vocabulary_.get(u'os')
# Out:
# 42292

# %%
count_vect.vocabulary_.get(u'mac')
# Out:
# 36430

# %%
tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_train_tf.shape
# Out:
# (2352, 60987)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (2352, 60987)

# %% [markdown]
# ## Étape 4: Construire le modèle

# %% [markdown]
# 1. classificateur bayesien naif

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, dataset.target)

# %% [markdown]
# Prediction

# %%
docs_new = ["Mac est une machine qui utilise le system d'exploitation mac os", "OpenGL on the GPU is fast"]
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)
predicted = clf.predict(X_new_tfidf)
for doc, category in zip(docs_new, predicted):
    print('%r => %s' % (doc, dataset.target_names[category]))
# Out:
# "Mac est une machine qui utilise le system d'exploitation mac os" => comp.sys.mac.hardware
# 'OpenGL on the GPU is fast' => comp.sys.ibm.pc.hardware

# %% [markdown]
# Construire un pipeline

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', MultinomialNB()),
])

# %%
text_clf.fit(dataset.data, dataset.target)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', MultinomialNB())])

# %% [markdown]
# ## Étape 5: Evaluation du modèle et de sa précision

# %%
import numpy as np
from sklearn import metrics

# %%
text_clf.fit(dataset.data, dataset.target)
dataset_test = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=42)
docs_test = dataset_test.data
predicted = text_clf.predict(docs_test)
np.mean(predicted == dataset_test.target)
# Out:
# 0.834610472541507

# %%
print(metrics.classification_report(dataset_test.target, predicted, target_names=dataset_test.target_names))
# Out:
#                           precision    recall  f1-score   support
#
#  comp.os.ms-windows.misc       0.84      0.73      0.78       394
# comp.sys.ibm.pc.hardware       0.72      0.89      0.80       392
#    comp.sys.mac.hardware       0.89      0.86      0.87       385
#           comp.windows.x       0.93      0.85      0.89       395
#
#                 accuracy                           0.83      1566
#                macro avg       0.84      0.83      0.84      1566
#             weighted avg       0.84      0.83      0.84      1566

# %%
metrics.confusion_matrix(dataset_test.target, predicted)
# Out:
# array([[289,  71,  15,  19],
#        [ 16, 350,  22,   4],
#        [ 13,  39, 331,   2],
#        [ 27,  25,   6, 337]])
